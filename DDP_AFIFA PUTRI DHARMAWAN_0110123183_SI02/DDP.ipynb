# %%
#deklarasi Dan inisialisasi variabel

Pelanggan = "Gabriel"
TotalBelanja = 150000

# %%
#struktur kendali if

if(TotalBelanja > 160000):
 keterangan = "Selamat Anda mendapatkan Hadiah"
else:
 keterangan = "Terima kasih sudah berbelanja "

# %%
#cetak data

print("Pelanggan",Pelanggan,"\nTotalBelanja anda Rp.",TotalBelanja,"\n",keterangan)
# Out:
# Pelanggan Gabriel
# TotalBelanja anda Rp. 150000
#  Terima kasih sudah berbelanja

# %%
#Siswa dinyatakan lulus minimal 60 nilainya
nama = "FIFA"
matkul = "PAI"
nilai = 80
#ternary
keterangan= "Lulus" if nilai >= 60 else "Gagal"

# %%
#cetak data
print("Nama siswa \t:",nama,
"\nMata kuliah \t:",matkul,
"\nNilai \t\t:",nilai,
"\nKeterangan \t:",keterangan)
# Out:
# Nama siswa 	: FIFA
# Mata kuliah 	: PAI
# Nilai 		: 80
# Keterangan 	: Lulus

# %%
nama = "Afifa Putri Dharmawan"
matkul = "PAI"
nilai = 90

# %%
usia = 20
nilai = 1

# %%
if usia >= 0 and usia <= 5:
    kategori_usia = "Balita"
elif usia >= 6 and usia < 12:
    kategori_usia = "Anak-anak"
elif usia >= 13 and usia < 17:
    kategori_usia = "Remaja"
elif usia >= 18 and usia < 55:
    kategori_usia = "Dewasa"
elif usia >= 56 and usia < 80:
    kategori_usia = "Lansia"
else:
    kategori_usia = "Tidak Diketahui"
# Out:
# Usia Anda adalah 20 tahun, dan Anda masuk dalam kategori Dewasa.

# %%
print(f"Usia Afifa adalah {usia} tahun, dan Anda masuk dalam kategori {kategori_usia}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9c9bab8ae83> in <cell line: 1>()
# ----> 1 print(f"Usia Afifa adalah {usia} tahun, dan Anda masuk dalam kategori {kategori_usia}.")
#
# NameError: name 'usia' is not defined

# %%
#Meminta pengguna memasukkan usia

nama = "Afifa"
usia = 20

#Menentukan kategori usia
if (usia <19):
  keterangan = "Anak-anak"
elif (usia <60):
  keterangan = "Dewasa"
else:
  keterangan = "Lanjut Usia"
#Cetak data
print("Nama", nama, "\nUsia", usia,"\n", keterangan)
print ()
# Out:
# Nama Afifa
# Usia 20
#  Dewasa

# %%
#Meminta pengguna memasukkan dua angka
angka1 = 1,3,5,7
angka2 = 7,9,11,13
#Membandingkan dua angka
if (angka1 > angka2):
  pesan = "Angka pertama lebih besar dari angka kedua."
elif (angka2 > angka1):
  pesan = "Angka kedua lebih besar dari angka pertama."
else:
  pesan = "Angka pertama dan angka kedua sama besar."
#Cetak data
print("Angka yang lebih besar adalah", pesan)
# Out:
# Angka yang lebih besar adalah Angka kedua lebih besar dari angka pertama.

# %%
#Meminta pengguna memasukkan dua angka
angka1 = 1,3,5,7
angka2 = 7,9,11,13
#Membandingkan dua angka
if (angka1 > angka2):
  pesan = "Angka pertama lebih besar dari angka kedua."
elif (angka2 > angka1):
  pesan = "Angka kedua lebih besar dari angka pertama."
else:
  pesan = "Angka pertama dan angka kedua sama besar."
#Cetak data
print("Angka yang lebih besar adalah", pesan)

#Meminta pengguna memasukkan usia
nama = "Afifa"
usia = 20
#Menentukan kategori usia
if (usia <19):
  keterangan = "Anak-anak"
elif (usia <60):
  keterangan = "Dewasa"
else:
  keterangan = "Lanjut Usia"
#Cetak data
print ()

print("Nama", nama,"\nUsia", usia, "\n", keterangan)
# Out:
# Angka yang lebih besar adalah Angka kedua lebih besar dari angka pertama.
#
# Nama Afifa
# Usia 20
#  Dewasa
