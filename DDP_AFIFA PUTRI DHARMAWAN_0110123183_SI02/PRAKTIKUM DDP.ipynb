# %%
Name="Afifa Putri Dharmawan"
NIM="0110123183"
Kelas="SI02"
NoTelpon="0895635807333"
Alamat="Jl.IrigasiNo66 RT.003/RW.07, Kemiri Muka,Kecamatan Beji,KotaDepok"

print(Name)
print(NIM)
print(NoTelpon)
print(Alamat)
# Out:
# Afifa Putri Dharmawan
# 0110123183
# 0895635807333
# Jl.IrigasiNo66RT.003/RW.07,KemiriMuka,KecamatanBeji,KotaDepok

# %%
Name="Zahra Alya Safitri"
NIM="0110123182"
Kelas="SI02"
NoTelpon="085781007374"
Alamat="Jl.Arifrahman Hakim"

print(Name)
print(NIM)
print(NoTelpon)
print(Alamat)
# Out:
# Zahra Alya Safitri
# 0110123182
# 085781007374
# Jl.Arifrahman Hakim

# %%
Zahra=62
Afifa=45
