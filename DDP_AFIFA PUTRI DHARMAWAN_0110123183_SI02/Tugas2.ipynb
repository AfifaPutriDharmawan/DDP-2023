# %%
print("Hai Kami dari Prodi SI")
# Out:
# hello prodi SI

# %%
print("Nama : Afifa Putri Dharmawan")
print("NIM : 0110123183")
print("Kelas : SI02")
# Out:
# Nama : Afifa Putri Dharmawan
# NIM : 0110123183
# Kelas : SI02
#
# Alamat : GG. Bunga RT. 01 RW.13
# Nama : Zahra Alya Sapitri
# NIM : 0110123182
# Alamat: Jl. Arif Rahman Hakiml

# %%
print("Nama : Zahra Alya Sapitri")
print("Alamat : GG. Bunga RT. 01 RW.13")
print("NIM : 0110123182")
print("Alamat: Jl. Arif Rahman Hakiml")
# Out:
# Nama : Zahra Alya Sapitri
# Alamat : GG. Bunga RT. 01 RW.13
# NIM : 0110123182
# Alamat: Jl. Arif Rahman Hakiml

# %%
print(25+2)
# Out:
# 27

# %%
print(100-1)
# Out:
# 99

# %%
print(200*5)
# Out:
# 1000

# %%
print(66/2)
# Out:
# 33.0

# %%
print(26**2)
# Out:
# 676

# %%
print(40/5)
# Out:
# 8.0
