# %%
panjang=5
lebar=10
luas=panjang*lebar

# %%
print(luas)
# Out:
# 50

# %%
print(panjang*lebar)
# Out:
# 50

# %%
print("hasilnya adalah:",luas)
# Out:
# hasilnya adalah: 50

# %%
alas=8
tinggi=10
luas=1/2*alas*tinggi

# %%
print(luas)
# Out:
# 40.0

# %%
print(1/2*alas*tinggi)
# Out:
# 40.0

# %%
print("hasilnya adalah",luas)
# Out:
# hasilnya adalah 40.0
