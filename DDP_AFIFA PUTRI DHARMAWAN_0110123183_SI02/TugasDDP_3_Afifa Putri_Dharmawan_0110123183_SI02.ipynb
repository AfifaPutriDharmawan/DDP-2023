# %%
Nama="Afifa Putri Dharmawan"
NIM="0110123183"
Kelas="SI02"
NoTelpon="0895635807333"
Alamat="Jl.IrigasiNo66RT.003/RW.07,KemiriMuka,KecamatanBeji,KotaDepok"

print(Nama)
print(NIM)
print(Kelas)
print(NoTelpon)
print(Alamat)
# Out:
# Afifa Putri Dharmawan
# 0110123183
# SI02
# 0895635807333
# Jl.IrigasiNo66RT.003/RW.07,KemiriMuka,KecamatanBeji,KotaDepok

# %%
Nama="Zahra alya sapitri"
Kelas="SI02"
Nim="0110123182"
Notelp="085781007374"
Alamat="Jl.arif rahman hakim"

print(Nama)
print(Kelas)
print(Nim)
print(Notelp)
print(Alamat)
# Out:
# Zahra alya sapitri
# SI02
# 0110123182
# 085781007374
# Jl.arif rahman hakim

# %%
Tb=162
Rumus=(162-100)-((162-100)*0.15)
print(Rumus)
# Out:
# 52.7

# %%
celc = 30

fahr = (9/5 * 30) + 32

print(fahr)
# Out:
# 86.0

# %%
Phi=22/7
R=40
Rumus_keliling_tabung=2*Phi*R
print(Rumus_keliling_tabung)
# Out:
# 251.42857142857142

# %%
Kendaraan = ["mobil","motor","sepeda","pesawat","kereta"]
Jenis_Kendaraan = ["matic","manual","batu bara"]
Cc_Kendaraan = [80,
